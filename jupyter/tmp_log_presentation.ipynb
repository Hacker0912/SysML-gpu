# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
# %matplotlib inline
import numpy as np
import seaborn as sns
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 8)
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
device_prefix = ['CPU', 'GPU']
models = ['logistic_regression', 'least_square', 'linear_svm']
#data_files = ['T_{}'.format(m) for m in (1000000, 2000000, 5000000, 10000000, 20000000, 50000000)]
data_files = ['T_{}'.format(m) for m in (1000000, 2000000, 5000000, 10000000)]
fit_choices = ['fitting', 'without_fit']

# %%
from itertools import product

def file_name_generator(device_prefix, models, data_files, fit_choices):
    file_names = []
    for i, comb in enumerate(product(device_prefix, models, data_files, fit_choices)):
        file_names.append((comb[0], comb[0]+'_'+comb[1]+'_'+comb[2]+'_'+comb[3]))
    return file_names

# %%
# generate file names
file_names = file_name_generator(device_prefix, models, data_files, fit_choices)

#for t in file_names:
#    print(t[0], t[1])

# %%
stats = {}
for i, f in enumerate(file_names):
    _prefix = './cpu_results/' if f[0] == 'CPU' else './gpu_results/'
    stats[f[1]] = {}
    with open(_prefix+f[1], 'rb') as log_file:
        iteration_counter = 0
        memory_movement_counter = 0
        computation_counter = 0
        reduce_counter = 0
        for line_index, line in enumerate(log_file.readlines()):
            line_content = line.rstrip('\n')
            if line_index == 0:
                stats[f[1]].update({'data_loading_time':float(line_content.split(':')[-1])})
            elif line_index == 1:
                stats[f[1]].update({'malloc_time':float(line_content.split(':')[-1])})
            else:
                iter_cost, memo_move_cost = line_content.split(',')[2], line_content.split(',')[3]
                comp_cost, reduce_cost = line_content.split(',')[4], line_content.split(',')[5]
                # count time
                iteration_counter += float(iter_cost.split(':')[-1])
                memory_movement_counter += float(memo_move_cost.split(':')[-1])
                computation_counter += float(comp_cost.split(':')[-1])
                reduce_counter += float(reduce_cost.split(':')[-1])
        
        stats[f[1]].update({'iter_cost':iteration_counter})
        stats[f[1]].update({'memory_movement_cost':memory_movement_counter})
        stats[f[1]].update({'computation_cost':computation_counter})
        stats[f[1]].update({'reduce_cost':reduce_counter})

# %%
print(stats.keys())
# Out:
# ['CPU_least_square_T_1000000_without_fit', 'GPU_logistic_regression_T_1000000_without_fit', 'CPU_linear_svm_T_10000000_fitting', 'CPU_least_square_T_2000000_fitting', 'CPU_logistic_regression_T_10000000_without_fit', 'CPU_logistic_regression_T_10000000_fitting', 'GPU_logistic_regression_T_10000000_without_fit', 'GPU_least_square_T_5000000_fitting', 'GPU_linear_svm_T_5000000_fitting', 'GPU_linear_svm_T_2000000_fitting', 'GPU_least_square_T_1000000_without_fit', 'GPU_least_square_T_2000000_fitting', 'GPU_least_square_T_10000000_without_fit', 'GPU_logistic_regression_T_10000000_fitting', 'CPU_least_square_T_10000000_without_fit', 'CPU_least_square_T_5000000_fitting', 'CPU_logistic_regression_T_1000000_without_fit', 'GPU_least_square_T_2000000_without_fit', 'CPU_linear_svm_T_1000000_without_fit', 'CPU_logistic_regression_T_5000000_fitting', 'CPU_least_square_T_1000000_fitting', 'CPU_linear_svm_T_1000000_fitting', 'CPU_logistic_regression_T_2000000_without_fit', 'GPU_least_square_T_5000000_without_fit', 'GPU_linear_svm_T_5000000_without_fit', 'GPU_linear_svm_T_10000000_without_fit', 'GPU_logistic_regression_T_1000000_fitting', 'CPU_linear_svm_T_10000000_without_fit', 'CPU_linear_svm_T_2000000_without_fit', 'CPU_least_square_T_10000000_fitting', 'CPU_logistic_regression_T_2000000_fitting', 'GPU_logistic_regression_T_5000000_without_fit', 'GPU_least_square_T_10000000_fitting', 'GPU_logistic_regression_T_2000000_without_fit', 'CPU_logistic_regression_T_5000000_without_fit', 'GPU_linear_svm_T_1000000_fitting', 'GPU_linear_svm_T_1000000_without_fit', 'CPU_least_square_T_5000000_without_fit', 'CPU_linear_svm_T_2000000_fitting', 'CPU_linear_svm_T_5000000_fitting', 'CPU_linear_svm_T_5000000_without_fit', 'GPU_logistic_regression_T_2000000_fitting', 'CPU_logistic_regression_T_1000000_fitting', 'GPU_linear_svm_T_10000000_fitting', 'GPU_linear_svm_T_2000000_without_fit', 'GPU_logistic_regression_T_5000000_fitting', 'CPU_least_square_T_2000000_without_fit', 'GPU_least_square_T_1000000_fitting']

# %%
for k, v in stats.items():
    print("File Name: {}".format(k))
    for sub_k, sub_v in v.items():
        print("Item: {}, Val: {}".format(sub_k, sub_v))
    print("-"*100)
# Out:
# File Name: CPU_least_square_T_1000000_without_fit
# Item: reduce_cost, Val: 0.9798
# Item: memory_movement_cost, Val: 26.8225
# Item: iter_cost, Val: 36.8658
# Item: data_loading_time, Val: 3.60035610199
# Item: malloc_time, Val: 0.000576972961426
# Item: computation_cost, Val: 10.0401
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_1000000_without_fit
# Item: reduce_cost, Val: 0.227
# Item: memory_movement_cost, Val: 29.8081
# Item: iter_cost, Val: 30.2305
# Item: data_loading_time, Val: 3.53979897499
# Item: malloc_time, Val: 0.00333189964294
# Item: computation_cost, Val: 0.4221
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_10000000_fitting
# Item: reduce_cost, Val: 9.4774
# Item: memory_movement_cost, Val: 0.0459
# Item: iter_cost, Val: 376.0088
# Item: data_loading_time, Val: 35.6351840496
# Item: malloc_time, Val: 0.26513504982
# Item: computation_cost, Val: 375.9584
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_2000000_fitting
# Item: reduce_cost, Val: 1.9245
# Item: memory_movement_cost, Val: 0.0259
# Item: iter_cost, Val: 19.9718
# Item: data_loading_time, Val: 7.25306606293
# Item: malloc_time, Val: 0.0553271770477
# Item: computation_cost, Val: 19.9431
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_10000000_without_fit
# Item: reduce_cost, Val: 9.5114
# Item: memory_movement_cost, Val: 257.8915
# Item: iter_cost, Val: 411.425
# Item: data_loading_time, Val: 35.7167210579
# Item: malloc_time, Val: 0.00465703010559
# Item: computation_cost, Val: 153.529
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_10000000_fitting
# Item: reduce_cost, Val: 9.5023
# Item: memory_movement_cost, Val: 0.0451
# Item: iter_cost, Val: 148.3797
# Item: data_loading_time, Val: 35.7702879906
# Item: malloc_time, Val: 0.265002965927
# Item: computation_cost, Val: 148.3299
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_10000000_without_fit
# Item: reduce_cost, Val: 1.9112
# Item: memory_movement_cost, Val: 302.8097
# Item: iter_cost, Val: 304.9477
# Item: data_loading_time, Val: 35.5593819618
# Item: malloc_time, Val: 0.0272660255432
# Item: computation_cost, Val: 2.138
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_5000000_fitting
# Item: reduce_cost, Val: 2.0426
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 2.1528
# Item: data_loading_time, Val: 17.9753189087
# Item: malloc_time, Val: 0.217842102051
# Item: computation_cost, Val: 2.1431
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_5000000_fitting
# Item: reduce_cost, Val: 3.7886
# Item: memory_movement_cost, Val: 0.0124
# Item: iter_cost, Val: 6.6505
# Item: data_loading_time, Val: 18.1714348793
# Item: malloc_time, Val: 0.218850135803
# Item: computation_cost, Val: 6.64
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_2000000_fitting
# Item: reduce_cost, Val: 3.0023
# Item: memory_movement_cost, Val: 0.0104
# Item: iter_cost, Val: 4.8283
# Item: data_loading_time, Val: 7.08995008469
# Item: malloc_time, Val: 0.0879440307617
# Item: computation_cost, Val: 4.8181
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_1000000_without_fit
# Item: reduce_cost, Val: 0.17
# Item: memory_movement_cost, Val: 29.7613
# Item: iter_cost, Val: 30.0965
# Item: data_loading_time, Val: 3.61372995377
# Item: malloc_time, Val: 0.00335001945496
# Item: computation_cost, Val: 0.336
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_2000000_fitting
# Item: reduce_cost, Val: 0.8359
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 0.9468
# Item: data_loading_time, Val: 7.20982217789
# Item: malloc_time, Val: 0.0872540473938
# Item: computation_cost, Val: 0.937
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_10000000_without_fit
# Item: reduce_cost, Val: 1.1342
# Item: memory_movement_cost, Val: 301.2519
# Item: iter_cost, Val: 302.5791
# Item: data_loading_time, Val: 35.5996999741
# Item: malloc_time, Val: 0.0275580883026
# Item: computation_cost, Val: 1.3272
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_10000000_fitting
# Item: reduce_cost, Val: 4.8552
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 4.9885
# Item: data_loading_time, Val: 35.983798027
# Item: malloc_time, Val: 0.435422182083
# Item: computation_cost, Val: 4.9787
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_10000000_without_fit
# Item: reduce_cost, Val: 9.5014
# Item: memory_movement_cost, Val: 258.0014
# Item: iter_cost, Val: 376.6541
# Item: data_loading_time, Val: 35.6343429089
# Item: malloc_time, Val: 0.00476598739624
# Item: computation_cost, Val: 118.6482
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_5000000_fitting
# Item: reduce_cost, Val: 4.7561
# Item: memory_movement_cost, Val: 0.0349
# Item: iter_cost, Val: 49.5201
# Item: data_loading_time, Val: 18.0531058311
# Item: malloc_time, Val: 0.134373903275
# Item: computation_cost, Val: 49.4827
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_1000000_without_fit
# Item: reduce_cost, Val: 0.9801
# Item: memory_movement_cost, Val: 26.4888
# Item: iter_cost, Val: 39.5205
# Item: data_loading_time, Val: 3.56630015373
# Item: malloc_time, Val: 0.000586032867432
# Item: computation_cost, Val: 13.0279
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_2000000_without_fit
# Item: reduce_cost, Val: 0.2773
# Item: memory_movement_cost, Val: 59.3685
# Item: iter_cost, Val: 59.8184
# Item: data_loading_time, Val: 7.13669395447
# Item: malloc_time, Val: 0.00584697723389
# Item: computation_cost, Val: 0.4498
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_1000000_without_fit
# Item: reduce_cost, Val: 0.9803
# Item: memory_movement_cost, Val: 27.1867
# Item: iter_cost, Val: 61.9634
# Item: data_loading_time, Val: 3.65385913849
# Item: malloc_time, Val: 0.000576019287109
# Item: computation_cost, Val: 34.7735
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_5000000_fitting
# Item: reduce_cost, Val: 4.7596
# Item: memory_movement_cost, Val: 0.0352
# Item: iter_cost, Val: 64.012
# Item: data_loading_time, Val: 17.8097269535
# Item: malloc_time, Val: 0.133677959442
# Item: computation_cost, Val: 63.9741
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_1000000_fitting
# Item: reduce_cost, Val: 0.9733
# Item: memory_movement_cost, Val: 0.0199
# Item: iter_cost, Val: 9.9302
# Item: data_loading_time, Val: 3.59348201752
# Item: malloc_time, Val: 0.0276861190796
# Item: computation_cost, Val: 9.9092
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_1000000_fitting
# Item: reduce_cost, Val: 0.9789
# Item: memory_movement_cost, Val: 0.0209
# Item: iter_cost, Val: 33.5626
# Item: data_loading_time, Val: 3.66631102562
# Item: malloc_time, Val: 0.0277168750763
# Item: computation_cost, Val: 33.5395
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_2000000_without_fit
# Item: reduce_cost, Val: 1.9281
# Item: memory_movement_cost, Val: 52.2244
# Item: iter_cost, Val: 77.868
# Item: data_loading_time, Val: 7.10917305946
# Item: malloc_time, Val: 0.00113606452942
# Item: computation_cost, Val: 25.6405
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_5000000_without_fit
# Item: reduce_cost, Val: 0.5952
# Item: memory_movement_cost, Val: 148.2552
# Item: iter_cost, Val: 149.031
# Item: data_loading_time, Val: 18.2374010086
# Item: malloc_time, Val: 0.0134501457214
# Item: computation_cost, Val: 0.7759
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_5000000_without_fit
# Item: reduce_cost, Val: 0.7489
# Item: memory_movement_cost, Val: 148.0053
# Item: iter_cost, Val: 149.913
# Item: data_loading_time, Val: 17.7496259212
# Item: malloc_time, Val: 0.0134479999542
# Item: computation_cost, Val: 1.9068
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_10000000_without_fit
# Item: reduce_cost, Val: 1.3569
# Item: memory_movement_cost, Val: 302.4904
# Item: iter_cost, Val: 305.9434
# Item: data_loading_time, Val: 36.5135338306
# Item: malloc_time, Val: 0.0273869037628
# Item: computation_cost, Val: 3.4532
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_1000000_fitting
# Item: reduce_cost, Val: 0.511
# Item: memory_movement_cost, Val: 0.0102
# Item: iter_cost, Val: 0.6406
# Item: data_loading_time, Val: 3.55786013603
# Item: malloc_time, Val: 0.0446150302887
# Item: computation_cost, Val: 0.6308
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_10000000_without_fit
# Item: reduce_cost, Val: 9.4822
# Item: memory_movement_cost, Val: 257.8743
# Item: iter_cost, Val: 637.144
# Item: data_loading_time, Val: 35.5554430485
# Item: malloc_time, Val: 0.00470805168152
# Item: computation_cost, Val: 379.2648
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_2000000_without_fit
# Item: reduce_cost, Val: 1.932
# Item: memory_movement_cost, Val: 53.394
# Item: iter_cost, Val: 121.0033
# Item: data_loading_time, Val: 7.28147292137
# Item: malloc_time, Val: 0.0011248588562
# Item: computation_cost, Val: 67.6056
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_10000000_fitting
# Item: reduce_cost, Val: 9.5012
# Item: memory_movement_cost, Val: 0.0452
# Item: iter_cost, Val: 115.7412
# Item: data_loading_time, Val: 36.6599290371
# Item: malloc_time, Val: 0.265174150467
# Item: computation_cost, Val: 115.6924
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_2000000_fitting
# Item: reduce_cost, Val: 1.9264
# Item: memory_movement_cost, Val: 0.028
# Item: iter_cost, Val: 25.8107
# Item: data_loading_time, Val: 7.14769911766
# Item: malloc_time, Val: 0.0552139282227
# Item: computation_cost, Val: 25.7814
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_5000000_without_fit
# Item: reduce_cost, Val: 0.9736
# Item: memory_movement_cost, Val: 147.7239
# Item: iter_cost, Val: 148.9113
# Item: data_loading_time, Val: 17.9941740036
# Item: malloc_time, Val: 0.0134949684143
# Item: computation_cost, Val: 1.1878
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_10000000_fitting
# Item: reduce_cost, Val: 4.0643
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 4.1789
# Item: data_loading_time, Val: 36.3516469002
# Item: malloc_time, Val: 0.433475017548
# Item: computation_cost, Val: 4.1689
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_2000000_without_fit
# Item: reduce_cost, Val: 0.4135
# Item: memory_movement_cost, Val: 59.2698
# Item: iter_cost, Val: 59.8867
# Item: data_loading_time, Val: 7.1330678463
# Item: malloc_time, Val: 0.00636696815491
# Item: computation_cost, Val: 0.6172
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_5000000_without_fit
# Item: reduce_cost, Val: 4.7626
# Item: memory_movement_cost, Val: 128.5197
# Item: iter_cost, Val: 192.6533
# Item: data_loading_time, Val: 18.0931618214
# Item: malloc_time, Val: 0.00293302536011
# Item: computation_cost, Val: 64.1292
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_1000000_fitting
# Item: reduce_cost, Val: 0.3011
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 0.7742
# Item: data_loading_time, Val: 3.54678487778
# Item: malloc_time, Val: 0.0449850559235
# Item: computation_cost, Val: 0.7646
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_1000000_without_fit
# Item: reduce_cost, Val: 0.185
# Item: memory_movement_cost, Val: 29.7766
# Item: iter_cost, Val: 30.3672
# Item: data_loading_time, Val: 3.57173109055
# Item: malloc_time, Val: 0.00334692001343
# Item: computation_cost, Val: 0.59
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_5000000_without_fit
# Item: reduce_cost, Val: 4.7711
# Item: memory_movement_cost, Val: 134.4425
# Item: iter_cost, Val: 184.4737
# Item: data_loading_time, Val: 17.7758350372
# Item: malloc_time, Val: 0.00249409675598
# Item: computation_cost, Val: 50.027
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_2000000_fitting
# Item: reduce_cost, Val: 1.9279
# Item: memory_movement_cost, Val: 0.0283
# Item: iter_cost, Val: 67.7718
# Item: data_loading_time, Val: 7.16712808609
# Item: malloc_time, Val: 0.0552859306335
# Item: computation_cost, Val: 67.7416
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_5000000_fitting
# Item: reduce_cost, Val: 4.7632
# Item: memory_movement_cost, Val: 0.0351
# Item: iter_cost, Val: 169.5243
# Item: data_loading_time, Val: 17.8403561115
# Item: malloc_time, Val: 0.134168863297
# Item: computation_cost, Val: 169.4872
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_linear_svm_T_5000000_without_fit
# Item: reduce_cost, Val: 4.7756
# Item: memory_movement_cost, Val: 129.4544
# Item: iter_cost, Val: 304.1574
# Item: data_loading_time, Val: 18.2799680233
# Item: malloc_time, Val: 0.00245714187622
# Item: computation_cost, Val: 174.6994
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_2000000_fitting
# Item: reduce_cost, Val: 0.9902
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 1.1185
# Item: data_loading_time, Val: 7.1134557724
# Item: malloc_time, Val: 0.0873968601227
# Item: computation_cost, Val: 1.1084
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_logistic_regression_T_1000000_fitting
# Item: reduce_cost, Val: 0.9758
# Item: memory_movement_cost, Val: 0.0202
# Item: iter_cost, Val: 12.7613
# Item: data_loading_time, Val: 3.6194357872
# Item: malloc_time, Val: 0.0278298854828
# Item: computation_cost, Val: 12.7395
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_10000000_fitting
# Item: reduce_cost, Val: 2.5696
# Item: memory_movement_cost, Val: 0.0131
# Item: iter_cost, Val: 6.2436
# Item: data_loading_time, Val: 35.516988039
# Item: malloc_time, Val: 0.449210166931
# Item: computation_cost, Val: 6.2327
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_linear_svm_T_2000000_without_fit
# Item: reduce_cost, Val: 0.3172
# Item: memory_movement_cost, Val: 59.5788
# Item: iter_cost, Val: 60.4906
# Item: data_loading_time, Val: 7.11594581604
# Item: malloc_time, Val: 0.00581121444702
# Item: computation_cost, Val: 0.9117
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_logistic_regression_T_5000000_fitting
# Item: reduce_cost, Val: 2.4357
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 2.5664
# Item: data_loading_time, Val: 17.9391801357
# Item: malloc_time, Val: 0.217001199722
# Item: computation_cost, Val: 2.5564
# ----------------------------------------------------------------------------------------------------
# File Name: CPU_least_square_T_2000000_without_fit
# Item: reduce_cost, Val: 1.9285
# Item: memory_movement_cost, Val: 54.6233
# Item: iter_cost, Val: 75.606
# Item: data_loading_time, Val: 7.49812197685
# Item: malloc_time, Val: 0.0011260509491
# Item: computation_cost, Val: 20.9796
# ----------------------------------------------------------------------------------------------------
# File Name: GPU_least_square_T_1000000_fitting
# Item: reduce_cost, Val: 0.435
# Item: memory_movement_cost, Val: 0.0101
# Item: iter_cost, Val: 0.5448
# Item: data_loading_time, Val: 3.54113912582
# Item: malloc_time, Val: 0.0445408821106
# Item: computation_cost, Val: 0.5356
# ----------------------------------------------------------------------------------------------------
